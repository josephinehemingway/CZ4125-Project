# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
def extract_basic_features(listing_html):
    url = "https://www.airbnb.com.sg" + listing_html.find('a').get('href')
    header = listing_html.find("div", {"class": "t1jojoys dir dir-ltr"}).get_text()
    name = listing_html.find("div", {"class": "nquyp1l s1cjsi4j dir dir-ltr"}).get_text()
    
    price = listing_html.find("div", {"class": "_1jo4hgw"}).get_text().split("\xa0")[-3].replace("$","")

    beds = listing_html.find_all("span", class_ = "dir dir-ltr")[0].get_text().split(" ")[0]
    
    try:
        ratings = listing_html.find("span", class_ = "t5eq1io r4a59j5 dir dir-ltr").get("aria-label").split(",")
        rate = ratings[0].split(" ")[0]
        review = ratings[1].split(" ")[-2]
    except:
        rate = np.nan
        review = np.nan
    
    pic = listing_html.find_all("source")[0].get("srcset")
    
    features_dict['header'].append(header)
    features_dict['url'].append(url)
    features_dict['name'].append(name)
    features_dict['price'].append(price)
    features_dict['beds'].append(beds)
    features_dict['rate'].append(rate)
    features_dict['review'].append(review)
    features_dict['pic'].append(pic)

# %%
def extract_page(url):
    soup = BeautifulSoup(requests.get(url).content, 'html.parser')
    listings = soup.find_all('div', 'cy5jw6o dir dir-ltr')
    
    for i in range(len(listings)):
        extract_basic_features(listings[i])

# %%
locations = ['Amsterdam','Paris','Lucerne','Interlaken','Milan']
df_list = []

# %%
for location in locations:
    airbnb_url = 'https://www.airbnb.com.sg/s/' + location + '/homes'
    soup = BeautifulSoup(requests.get(airbnb_url).content, 'html.parser')
    next_page = ['https://www.airbnb.com.sg' + x.get('href') for x in soup.find("div",class_="_jro6t0").find_all('a')]
    
    features_dict = {}

    features = ['header','url','name','price','beds','rate','review','pic']

    for feat in features:
        features_dict[feat] = []

    extract_page(airbnb_url)
    extract_page(next_page[0])
    extract_page(next_page[1])

    df = pd.DataFrame(features_dict)
    
    df_list.append(df)

# %%
df_list[0]
# Out:
#                                header  \
# 0              Loft in Stadsdeel Oost
# 1      Private room in Stadsdeel West
# 2   Private room in Stadsdeel Centrum
# 3      Private room in Stadsdeel West
# 4      Apartment in Stadsdeel Centrum
# 5           Flat in Stadsdeel Centrum
# 6      Private room in Stadsdeel Zuid
# 7             Flat in Stadsdeel Noord
# 8           Flat in Stadsdeel Centrum
# 9   Private room in Stadsdeel Centrum
# 10             Flat in Stadsdeel Zuid
# 11   Guest suite in Stadsdeel Centrum
# 12          Flat in Stadsdeel Centrum
# 13          Flat in Stadsdeel Centrum
# 14          Flat in Stadsdeel Centrum
# 15  Private room in Stadsdeel Centrum
# 16  Private room in Stadsdeel Centrum
# 17          Loft in Stadsdeel Centrum
# 18     Private room in Stadsdeel West
# 19  Private room in Stadsdeel Centrum
# 20     Private room in Stadsdeel West
# 21  Private room in Stadsdeel Centrum
# 22  Private room in Stadsdeel Centrum
# 23    Hotel room in Stadsdeel Centrum
# 24     Private room in Stadsdeel Zuid
# 25  Private room in Stadsdeel Centrum
# 26     Private room in Stadsdeel Zuid
# 27     Private room in Stadsdeel Zuid
# 28     Private room in Stadsdeel West
# 29          Flat in Stadsdeel Centrum
# 22    City centre apartment 2 on corner of two canals   200    1  4.96     45
# 23                Room in a charming canal house - 23   133    1  4.74    179
# 24                        Prime location in "De Pijp"   124    1  4.83     54
# 25                            Comfortable double room   123    1  4.88    453
# 26                 Studio in the “Pijp” near hotspots   138    2   4.8    304
# 27                       Cosy single room with a view   108    1  4.94    221
# 28      Private studio at houseboat Alma in Amsterdam   174    1  4.97    119
# 29            Simple stay in amazing place (1 person)   114    2   NaN    NaN
# 30                         Private Stairway to heaven   174    1  4.93    509
# 31          Houseboat, B&B in the back stern (BK 53).   135    1  4.88    153
# 32    Private studio in Jordaan area  for 1-3 persons   127    3  4.66     47
# 33    Big Bed in private room in CENTER of AMSTERDAM!   102    1  4.57    433
# 34               Comfortable Room with private Shower   144    1  4.91    176
# 35                              Amsterdam city garden   166    1   4.9     10
# 36                    Cosy apartment near city center   172    1  4.85     82
# 37      Cute and cosy ground floor well designed flat    97    1   5.0      5
# 38              DELUXE ROOM near centre easy parking!    99    1  4.55    327
# 39   Govert Flinckstraat (close to Albert Cuyp markt)   211    3   5.0     20
# 40                   Quiet room with free car parking    63    2  4.82    354
# 41  Nice room in the neigboorhood of Amsterdam/Air...    49    1  4.75    173
# 42                      Generator - Bed in 4 bed Dorm    63    1   4.5   1164
# 43    Big Bed in private room in CENTER of AMSTERDAM!   102    1  4.57    433
# 44                             Canal Boat City Center   303    1  4.88    193
# 45          Private & Cosy design Studio in Amsterdam   125    1  4.83     96
# 46       TOPLOCATED room, private bath, 5 walkmins CS   193    1  4.58    111
# 47   Cat lover for discount house in Amsterdam Noord.   100    2   NaN    NaN
# 48                              Amsterdam city garden   166    1   4.9     10
# 49        Spacious Serviced Apartment with River View   850    5  4.81    272
# 50             Eco-friendly Double Room by Vondelpark   167    1  4.72   1418
# 51                Spectacular Loft - central & quiet!   300    1  4.92    431
# 52    Private studio in Jordaan area  for 1-3 persons   127    3  4.66     47
# 53      Canal View Amsterdam Brouwersgracht apartment   206    2  4.88     76
# 54                     Charming room near the centrum   111    1  4.73    207
# 55              DELUXE ROOM near centre easy parking!    99    1  4.55    327
# 56                       Rural home close to downtown    82    1  4.55    404
# 57  Attic space with private shower - toilet (1per...    97    1  4.84     76
# 58   Knusse woonboot met parking in centrum Amsterdam   296    3  4.98     49
# 59     Trendy Serviced Apartment near Central Station   357    3  4.78    724
#
#                                                   pic
# 0   https://a0.muscache.com/im/pictures/miso/Hosti...
# 1   https://a0.muscache.com/im/pictures/b0e68619-6...
# 2   https://a0.muscache.com/im/pictures/162009/bd6...
# 3   https://a0.muscache.com/im/pictures/miso/Hosti...
# 4   https://a0.muscache.com/im/pictures/24494657/f...
# 5   https://a0.muscache.com/im/pictures/0fb83e89-4...
# 6   https://a0.muscache.com/im/pictures/110141486/...
# 7   https://a0.muscache.com/im/pictures/miso/Hosti...
# 8   https://a0.muscache.com/im/pictures/49203327/a...
# 9   https://a0.muscache.com/im/pictures/c721181e-b...
