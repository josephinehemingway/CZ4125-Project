# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
def extract_basic_features(listing_html):
    url = "https://www.airbnb.com.sg" + listing_html.find('a').get('href')
    header = listing_html.find("div", {"class": "t1jojoys dir dir-ltr"}).get_text()
    name = listing_html.find("div", {"class": "nquyp1l s1cjsi4j dir dir-ltr"}).get_text()
    
    price = listing_html.find("div", {"class": "_1jo4hgw"}).get_text().split("\xa0")[-3].replace("$","")

    beds = listing_html.find_all("span", class_ = "dir dir-ltr")[0].get_text().split(" ")[0]
    
    try:
        ratings = listing_html.find("span", class_ = "t5eq1io r4a59j5 dir dir-ltr").get("aria-label").split(",")
        rate = ratings[0].split(" ")[0]
        review = ratings[1].split(" ")[-2]
    except:
        rate = np.nan
        review = np.nan
    
    pic = listing_html.find_all("source")[0].get("srcset")
    
    features_dict['header'].append(header)
    features_dict['url'].append(url)
    features_dict['name'].append(name)
    features_dict['price'].append(price)
    features_dict['beds'].append(beds)
    features_dict['rate'].append(rate)
    features_dict['review'].append(review)
    features_dict['pic'].append(pic)

# %%
def extract_page(url):
    soup = BeautifulSoup(requests.get(url).content, 'html.parser')
    listings = soup.find_all('div', 'cy5jw6o dir dir-ltr')
    
    for i in range(len(listings)):
        extract_basic_features(listings[i])

# %%
locations = ['Amsterdam','Paris','Lucerne','Interlaken','Milan']
df_list = []

# %%
for location in locations:
    airbnb_url = 'https://www.airbnb.com.sg/s/' + location + '/homes'
    soup = BeautifulSoup(requests.get(airbnb_url).content, 'html.parser')
    next_page = ['https://www.airbnb.com.sg' + x.get('href') for x in soup.find("div",class_="_jro6t0").find_all('a')]
    
    features_dict = {}

    features = ['header','url','name','price','beds','rate','review','pic']

    for feat in features:
        features_dict[feat] = []

    extract_page(airbnb_url)
    extract_page(next_page[0])
    extract_page(next_page[1])

    df = pd.DataFrame(features_dict)
    
    df_list.append(df)

# %%
df_list[0]
# Out:
#                                header  \
# 0      Private room in Stadsdeel Oost
# 1      Townhouse in Stadsdeel Centrum
# 2              Loft in Stadsdeel Oost
# 3      Private room in Stadsdeel West
# 4           Flat in Stadsdeel Centrum
# 5      Houseboat in Stadsdeel Centrum
# 6      Private room in Stadsdeel West
# 7             Flat in Stadsdeel Noord
# 8   Private room in Stadsdeel Centrum
# 9           Flat in Stadsdeel Centrum
# 10          Flat in Stadsdeel Centrum
# 11     Private room in Stadsdeel Zuid
# 12  Private room in Stadsdeel Centrum
# 13     Private room in Stadsdeel Zuid
# 14             Flat in Stadsdeel West
# 15  Private room in Stadsdeel Centrum
# 16          Flat in Stadsdeel Centrum
# 17  Private room in Stadsdeel Centrum
# 18     Private room in Stadsdeel Zuid
# 19             Flat in Stadsdeel West
# 20          Private room in Amsterdam
# 21            Private room in Zaandam
# 22          Private room in Amsterdam
# 23            Hotel room in Amsterdam
# 24           Guest house in Amsterdam
# 25          Private room in Amsterdam
# 26          Private room in Amsterdam
# 27             Apartment in Amsterdam
# 28             Apartment in Amsterdam
# 29          Private room in Amsterdam
# 30          Private room in Amsterdam
# 31                  Flat in Amsterdam
# 32             Apartment in Amsterdam
# 24                 Top location, quiet guesthouse, 2p   246    1  4.94    159
# 25           BrightRoom II - Forest View Rembrandpark    89    1  4.89     19
# 26                            Comfortable double room   123    1  4.88    448
# 27              Central & Clean APT w WiFi @ De Pijp!   198    1  4.92     13
# 28  Central | Clean | Cozy APT & Roof Terrace @ De...   195    1   5.0     10
# 29  Clean cozy canalview room + bathroom for 1 per...   140    1   5.0     84
# 30                                           Big room    82    1  4.85    276
# 31       Modern & cozy apartment next to Amstel river   221    1   4.9     42
# 32  Ruim huis (105m2) met tuin + werkplek in Amste...   272    1   NaN    NaN
# 33                    Cosy apartment near city center   171    1  4.85     82
# 34  Nice room in the neigboorhood of Amsterdam/Air...    43    1  4.75    173
# 35                Modern cozy apartment in Javastraat   171    1  4.52     42
# 36  Lovely bright room with balcony and beatiful v...   108    1  4.42    510
# 37         High-end boutique studio near city center!   157    1  4.43      7
# 38          Light and cozy apartment near the centre!    99    1   NaN    NaN
# 39  Comfortable stay in museum district for one or...   108    2  4.66    227
# 40  Small room in Haarlem  between Amsterdam and c...    62    1  4.73    176
# 41      Central, Modern & Clean APT w WiFi @ Jordaan!   206    1   5.0     11
# 42  Quiet nice room for one person; close to airport.    58    1  4.94     18
# 43                         Private Stairway to heaven   173    1  4.93    504
# 44                 Studio in the “Pijp” near hotspots   138    2   4.8    303
# 45  Trendy room near Amsterdam. Free Parking & Net...    88    1  4.85     13
# 46          Houseboat, B&B in the back stern (BK 53).   156    1  4.87    151
# 47  Private studio Modern Houseboat Large Roof Ter...   133    2  4.78    421
# 48                         Canal LOFT, great LOCATION   227    2  4.58    103
# 49                          Buenas Noches - The Haven   114    1  4.83    423
# 50  THE LITTLE LOFT (private apartment in the center)   231    1  4.76    215
# 51                 Cozy dormer room in the old center   154    1  4.59    138
# 52  Relaxing Luxury Room  | OntheAmstel | 📢🐈&🐶 lovers   168    1  4.95    195
# 53      Private clean room near Utrecht and Amsterdam    49    1   4.8    135
# 54          Citiez Hotel Amsterdam: Small Double Room   107    1  4.65   1779
# 55                       First class houseboat studio   277    1  4.96    332
# 56    Bright Top Floor Loft on the Corner of 2 Canals   410    1   5.0      7
# 57   Govert Flinckstraat (close to Albert Cuyp markt)   247    3   5.0     20
# 58  | Central, Modern & Clean APT @ AMS City Center |   226    1   5.0      8
# 59      ''Romantic and tastefully decorated Boudoir''   166    3   4.9    277
#
#                                                   pic
# 0   https://a0.muscache.com/im/pictures/61aa2f50-6...
# 1   https://a0.muscache.com/im/pictures/86821432/9...
# 2   https://a0.muscache.com/im/pictures/miso/Hosti...
# 3   https://a0.muscache.com/im/pictures/miso/Hosti...
# 4   https://a0.muscache.com/im/pictures/49203327/a...
# 5   https://a0.muscache.com/im/pictures/39184835-7...
# 6   https://a0.muscache.com/im/pictures/27499ed4-a...
# 7   https://a0.muscache.com/im/pictures/miso/Hosti...
# 8   https://a0.muscache.com/im/pictures/miso/Hosti...
# 9   https://a0.muscache.com/im/pictures/8cbb08e8-2...
